# %%
import numpy as np
import pymongo
import re

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.VideoGamesDB

# %%
results = db.steam.find({'genres':'Action'})

# %%
for result in results:
    print(result)
# Out:
# id': ObjectId('60c2ae9740e537af1fc672a7'), 'name': 'One Gun: Cat', 'platforms': 'windows', 'release_date': datetime.datetime(2018, 10, 19, 0, 0), 'genres': 'Action', 'developer': 'Erow.Dev', 'publisher': 'Erow.Dev', 'positive_ratings': 32, 'negative_ratings': 9, 'platforms_steam': 'Steam', 'release_year': 2018}
# {'_id': ObjectId('60c2ae9740e537af1fc672a9'), 'name': 'Conjure Strike', 'platforms': 'windows', 'release_date': datetime.datetime(2018, 9, 28, 0, 0), 'genres': 'Action', 'developer': 'The Strike Team', 'publisher': 'The Strike Team', 'positive_ratings': 1, 'negative_ratings': 2, 'platforms_steam': 'Steam', 'release_year': 2018}
# ...

# %%
# results = db.console.find({'User_Score': {'$ne': 'tbd'}})
# results = db.console.find({'User_Score': {'$ne': np.nan}})
results = db.console.find({'$and': [
    {'User_Score': {'$ne':np.nan}},
    {'User_Score': {'$ne': 'tbd'}},
    {'Name': {'$regex':'duty', '$options':'i'}}
    ]})

# %%
results = db.console.find({'Name': {'$regex':'fifa', '$options':'i'} })
# results = db.console.find({'Name': {'$regex': '^mario$', '$options' : 'i'} })

# %%
results = db.steam.find({'$and': [
    {'User_Score': {'$ne':np.nan}},
    {'User_Score': {'$ne': 'tbd'}},
    {'Name': {'$regex':'fifa', '$options':'i'}}
    ]})

# %%
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('60c2ae3e40e537af1fc5d2b2'), 'Name': 'Call of Duty: Modern Warfare 3', 'Platform': 'X360', 'Year_of_Release': 2011.0, 'Genre': 'Shooter', 'Developer': 'Infinity Ward, Sledgehammer Games', 'Publisher': 'Activision', 'User_Score': '3.4'}
# {'_id': ObjectId('60c2ae3e40e537af1fc5d2b5'), 'Name': 'Call of Duty: Black Ops', 'Platform': 'X360', 'Year_of_Release': 2010.0, 'Genre': 'Shooter', 'Developer': 'Treyarch', 'Publisher': 'Activision', 'User_Score': '6.3'}
# {'_id': ObjectId('60c2ae3e40e537af1fc5d2b7'), 'Name': 'Call of Duty: Black Ops II', 'Platform': 'PS3', 'Year_of_Release': 2012.0, 'Genre': 'Shooter', 'Developer': 'Treyarch', 'Publisher': 'Activision', 'User_Score': '5.3'}
# {'_id': ObjectId('60c2ae3e40e537af1fc5d2b8'), 'Name': 'Call of Duty: Black Ops II', 'Platform': 'X360', 'Year_of_Release': 2012.0, 'Genre': 'Shooter', 'Developer': 'Treyarch', 'Publisher': 'Activision', 'User_Score': '4.8'}
# ...
